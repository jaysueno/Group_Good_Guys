# %%
# import dependencies

import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import numpy as np

# %%
# call first file

shades_grey_df = pd.read_csv('Resources/shadesgrey2015.csv')

# %%
# rename columns
grey_rename_df = shades_grey_df.rename(columns={'Market 2015': 'Country',
                                               'Region 2015': 'Region',
                                               '$ Opening Day Sales 2015': 'Opening Day Sales 2015',
                                               '$ Gross Sales 2015': 'Gross Sales 2015'})
grey_rename_df.head()
# Out:
#          Country                           Region Release Date 2015  \
# 0  United States                    North America         2/13/2015
# 1        Austria  Europe, Middle East, and Africa         2/12/2015
# 2        Belgium  Europe, Middle East, and Africa         2/11/2015
# 3       Bulgaria  Europe, Middle East, and Africa         2/13/2015
# 4        Croatia  Europe, Middle East, and Africa         2/12/2015
#
#    Opening Day Sales 2015  Gross Sales 2015
# 0                85171450         166167230
# 1                 1607134           5397769
# 2                 2102437           5792486
# 3                  336509            837393
# 4                  331540            694309

# %%
# call second file
shades_darker_df = pd.read_csv('Resources/shadesdarker2017.csv')

# %%
# rename columns
darker_rename_df = shades_darker_df.rename(columns={'Market 2017': 'Country',
                                                   'Region 2017': 'Region',
                                                   '$ Opening Day Sales 2017': 'Opening Day Sales 2017',
                                                   '$ Gross Sales 2017': 'Gross Sales 2017'})

# %%
# merge first and second files - Combined Data Set from Two CSV files
shades_df = pd.merge(grey_rename_df,darker_rename_df)
shades_df.head()
# Out:
#          Country                           Region Release Date 2015  \
# 0  United States                    North America         2/13/2015
# 1        Austria  Europe, Middle East, and Africa         2/12/2015
# 2        Belgium  Europe, Middle East, and Africa         2/11/2015
# 3       Bulgaria  Europe, Middle East, and Africa         2/13/2015
# 4        Croatia  Europe, Middle East, and Africa         2/12/2015
#
#    Opening Day Sales 2015  Gross Sales 2015 Release Date 2017  \
# 0                85171450         166167230         2/10/2017
# 1                 1607134           5397769         2/10/2017
# 2                 2102437           5792486          2/8/2017
# 3                  336509            837393         2/10/2017
# 4                  331540            694309          2/9/2017
#
#   Opening Day Sales 2017  Gross Sales 2017
# 0               46607250         114581250
# 1                1019875           4628670
# 2                1295138            619814
# 3                 172707            520005
# 4                 162397            222750

# %%
# Make a dataframe with only the target countries

x_target = ['Germany', 'Mexico', 'Philippines', 'Singapore', 'United Kingdom', 'United States']

y_gross_2015 = [41430653, 14148888, 3565511, 1837395, 51603774, 166167230]
y_opening_2015 = [14135994, 5495154, 2047933,  641621, 20876148, 85171450]

y_gross_2017 = [32709880, 6534100, 3399902, 1031387, 28583660, 114581250]
y_opening_2017 = [8529213, 2692197, 1803492, 369593, 9241277, 46607250]

y_ticks_gross  = [0,25000000,50000000,75000000,100000000,125000000,150000000,175000000,200000000]
y_labels_gross = ['$0','$25,000,000','$50,000,000','$75,000,000','$100,000,000','$125,000,000','$150,000,000','175,000,000','$200,000,000']

y_ticks_open = [0,20000000,40000000,60000000,80000000,100000000]
y_labels_open = ['$0','$20,000,000','$40,000,000','$60,000,000','$80,000,000','$100,000,000']

y_ticks_gross17 = [0,25000000,50000000,75000000,100000000,125000000]
y_labels_gross17 = ['$0','$25,000,000','$50,000,000','$75,000,000','$100,000,000','$125,000,000']

y_ticks_open17 = [0,10000000,20000000,30000000,40000000,50000000]
y_labels_open17 = ['$0','$10,000,000','$20,000,000','$30,000,000','$40,000,000','$50,000,000']

# %%
# Make Bar Chart with Target Country from Each Region which shows Opening Day Ticket Sales 2015

plt.bar(x_target, y_opening_2015)
plt.xticks(rotation=90)
plt.title('Opening Day Ticket Sales - 50 Shades of Grey (2015)')
plt.yticks(ticks=y_ticks_open,labels=y_labels_open)
plt.tight_layout()
plt.grid()
plt.savefig('Charts/Bar_OpeningSales2015.png')

# %%
# Make Bar Chart with Target Country from Each Region which shows Gross Ticket Sales 2015

plt.bar(x_target, y_gross_2015)
plt.xticks(rotation=90)
plt.title('Gross Movie Ticket Sales - 50 Shades of Grey (2015)')
plt.yticks(ticks=y_ticks_gross,labels=y_labels_gross)
plt.tight_layout()
plt.grid()
plt.savefig('Charts/Bar_GrossSales2015.png')

# %%
# Make Bar Chart with Target Country from Each Region which shows Opening Day Ticket Sales 2017

plt.bar(x_target, y_opening_2017)
plt.xticks(rotation=90)
plt.title('Opening Day Ticket Sales - 50 Shades Darker (2017)')
plt.yticks(ticks=y_ticks_open17,labels=y_labels_open17)
plt.tight_layout()
plt.grid()
plt.savefig('Charts/Bar_OpeningSales2017.png')

# %%
# Make Bar Chart with Target Country from Each Region which shows Gross Ticket Sales 2017

plt.bar(x_target, y_gross_2017)
plt.xticks(rotation=90)
plt.title('Gross Ticket Sales - 50 Shades Darker (2017)')
plt.yticks(ticks=y_ticks_gross17,labels=y_labels_gross17)
plt.tight_layout()
plt.grid()
plt.savefig('Charts/Bar_GrossSales2017.png')

# %%
# Country by 50 Shades of Grey Opening Day Sales

x = shades_df['Country']
y = shades_df['Opening Day Sales 2015']
plt.bar(x, y)
plt.title('Opening Day Sales 2015 By Country')
plt.xlabel('Country')
plt.ylabel('Sales')
plt.xticks(rotation=90)
plt.tight_layout()
plt.savefig('Charts/BarShadesOfGrey_OpeningSalesByCountry2015.png')

# %%
# Countries by 50 Shades of Grey Gross Sales

x = shades_df['Country']
y = shades_df['Gross Sales 2015']
plt.bar(x,y)
plt.title('Gross Sales 2015 By Country')
plt.xlabel('Country')
plt.ylabel('Sales')
plt.xticks(rotation=90)
plt.tight_layout()
plt.savefig('Charts/BarShadesOfGrey_GrossSalesByCountry2015')

# %%
# call happiness files
h15_df = pd.read_csv('Resources/Happiness_data_clean_2015.csv')
h16_df = pd.read_csv('Resources/Happiness_data_clean_2016.csv')
h17_df = pd.read_csv('Resources/Happiness_data_clean_2017.csv')

# %%
# merge Happiness Data from 2015 and 50 Shades of Grey which was released in 2015
merged15_df = pd.merge(h15_df, shades_df)

# %%
# rename index and alphabetize by country
merged15_df = merged15_df.sort_values(by='Country')
merged15_df.set_index('Country').head()
# Out:
#            2015_rank  2015_score  2015_GDP  2015_family  2015_life_expect  \
# Country
# Argentina         30       6.574   1.05351      1.24823           0.78723
# Australia         10       7.284   1.33358      1.30923           0.93156
# Austria           13       7.200   1.33723      1.29704           0.89042
# Belgium           19       6.937   1.30782      1.28566           0.89667
# Bolivia           51       5.890   0.68133      0.97841           0.53920
#
#            2015_freedom  2015_corruption  2015_generosity  2015_Dystopia  \
# Country
# Argentina       0.44974          0.08484          0.11451        2.83600
# Australia       0.65124          0.35637          0.43562        2.26646
# Austria         0.62433          0.18676          0.33088        2.53320
# Belgium         0.58450          0.22540          0.22250        2.41484
# Bolivia         0.57414          0.08800          0.20536        2.82334
#
#                                     Region Release Date 2015  \
# Country
# Argentina                    Latin America         2/12/2015
# Australia                     Asia Pacific         2/12/2015
# Austria    Europe, Middle East, and Africa         2/12/2015
# Belgium    Europe, Middle East, and Africa         2/11/2015
# Bolivia                      Latin America         2/12/2015
#
#            Opening Day Sales 2015  Gross Sales 2015 Release Date 2017  \
# Country
# Argentina                 3219933           3222236          2/9/2017
# Australia                 8116405          18229895          2/9/2017
# Austria                   1607134           5397769         2/10/2017
# Belgium                   2102437           5792486          2/8/2017
# Bolivia                    127602            481608          2/9/2017
#
#           Opening Day Sales 2017  Gross Sales 2017
# Country
# Argentina                2238126           3724443
# Australia                4732691          13785620
# Austria                  1019875           4628670
# Belgium                  1295138            619814
# Bolivia                   105252            339876

# %%
# Create a ScatterPlot comparing Opening Day Sales of 50 Shades of Grey in 2015 vs World Happiness Rank 2015 by country

x = merged15_df['2015_rank']
y = merged15_df['Opening Day Sales 2015']
plt.scatter(x, y)
plt.title('Opening Day Sales 2015 vs Happiness Rank 2015')
plt.xlabel('Happiness Rank 2015')
plt.yticks(ticks=y_ticks_open,labels=y_labels_open)
plt.tight_layout()
plt.grid()
plt.savefig('Charts/2015OpeningSalesVSHappiness.png')

# %%
# Create a ScatterPlot comparings Gross Sales of 50 Shades of Grey in 2015 vs World Happiness Rank 2015 by country

x = merged15_df['2015_rank']
y = merged15_df['Gross Sales 2015']
plt.scatter(x, y)
plt.title('Gross Sales 2015 vs. Happiness Rank 2015')
plt.xlabel('Happiness Rank 2015 (Lower Number Means Higher Rank)')
plt.yticks(ticks=y_ticks_gross,labels=y_labels_gross)
plt.tight_layout()
plt.grid()
plt.savefig('Charts/2015GrossSalesVSHappiness.png')

# %%
# merge Happiness Data from 2017 and 50 Shades Darker, the sequel to 50 Shades of Grey, which was released in 2017.
# Sorted Country index alphabetically
# set index to alphabetized County column

merged17_df = pd.merge(h17_df, shades_df)
merged17_df = merged17_df.sort_values('Country')
merged17_df = merged17_df.set_index('Country')
merged17_df
# Out:
#                 2017_rank  2017_score  2017_GDP  2017_family  \
# Country
# Argentina              24       6.599  1.185295     1.440451
# Australia              10       7.284  1.484415     1.510042
# Austria                13       7.006  1.487097     1.459945
# Belgium                17       6.891  1.463781     1.462313
# Bolivia                58       5.823  0.833757     1.227619
# Brazil                 22       6.635  1.107353     1.431306
# Bulgaria              105       4.714  1.161459     1.434379
# Chile                  20       6.652  1.252785     1.284025
# Colombia               36       6.357  1.070622     1.402183
# Croatia                77       5.293  1.222556     0.967983
# Czech Republic         23       6.609  1.352682     1.433885
# Denmark                 2       7.522  1.482383     1.551122
# Ecuador                44       6.008  1.000820     1.286169
# Estonia                66       5.611  1.320879     1.476671
# Finland                 5       7.469  1.443572     1.540247
# France                 31       6.442  1.430923     1.387777
# Germany                16       6.951  1.487923     1.472520
# Greece                 87       5.227  1.289487     1.239415
# Hungary                75       5.324  1.286012     1.343133
# Iceland                 3       7.504  1.480633     1.610574
# Thailand                0.647239      0.580201         0.572123
# Turkey                  0.637606      0.300741         0.046693
# Ukraine                 0.575904      0.122975         0.270061
# United Kingdom          0.805336      0.508190         0.492774
# United States           0.774287      0.505741         0.392579
# Uruguay                 0.719217      0.579392         0.175097
#
#                 2017_corruption  2017_Dystopia  \
# Country
# Argentina              0.059740       2.614005
# Australia              0.301184       2.065211
# Austria                0.221060       2.138506
# Belgium                0.251343       2.124210
# Bolivia                0.060478       2.443279
# Brazil                 0.111093       2.769267
# Bulgaria               0.011052       0.996139
# Chile                  0.082288       2.509586
# Colombia               0.046669       2.616068
# Croatia                0.043103       1.854492
# Czech Republic         0.036873       2.451862
# Denmark                0.400770       2.313707
# Ecuador                0.140135       2.290353
# Estonia                0.183249       1.357509
# Finland                0.382612       2.430182
# France                 0.172502       2.005955
# Germany                0.276732       2.015770
# Greece                 0.043290       1.749222
# Hungary                0.036637       1.716459
# Iceland                0.153527       2.322715
# Israel                 0.085242       2.801757
# Italy                  0.028028       1.813312
# Latvia                 0.073843       1.993655
# Lebanon                0.037514       1.695074
# Lithuania              0.011866       2.228441
# Mexico                 0.132774       2.837155
# Netherlands            0.282662       2.294804
# New Zealand            0.382817       2.046456
# Norway                 0.315964       2.277027
# Peru                   0.047049       2.207269
# Philippines            0.099332       1.972605
# Poland                 0.059308       1.797723
# Portugal               0.015869       1.107683
# Romania                0.004388       2.176831
# Singapore              0.464308       1.216362
# Slovakia               0.024211       2.097777
# Slovenia               0.045129       1.313317
# South Africa           0.072509       1.510909
# South Korea            0.063283       1.880378
# Spain                  0.070914       1.927758
# Sweden                 0.384399       2.097538
# Thailand               0.031613       2.039508
# Turkey                 0.099672       1.879278
# Ukraine                0.023029       0.814382
# United Kingdom         0.265428       1.704144
# United States          0.135639       2.218113
# Uruguay                0.178062       2.172410
#
#                                          Region Release Date 2015  \
# Country
# Argentina                         Latin America         2/12/2015
# Australia                          Asia Pacific         2/12/2015
# Austria         Europe, Middle East, and Africa         2/12/2015
# Belgium         Europe, Middle East, and Africa         2/11/2015
# Bolivia                           Latin America         2/12/2015
# Brazil                            Latin America         2/12/2015
# Bulgaria        Europe, Middle East, and Africa         2/13/2015
# Chile                             Latin America         2/12/2015
# Colombia                          Latin America         2/12/2015
# Croatia         Europe, Middle East, and Africa         2/12/2015
# Czech Republic  Europe, Middle East, and Africa         2/12/2015
# Denmark         Europe, Middle East, and Africa         2/12/2015
# Ecuador                           Latin America         2/13/2015
# Estonia         Europe, Middle East, and Africa         2/13/2015
# Finland         Europe, Middle East, and Africa         2/13/2015
# France          Europe, Middle East, and Africa         2/11/2015
# Germany         Europe, Middle East, and Africa         2/12/2015
# Greece          Europe, Middle East, and Africa         2/12/2015
# Hungary         Europe, Middle East, and Africa         2/12/2015
# Iceland         Europe, Middle East, and Africa         2/13/2015
# Israel          Europe, Middle East, and Africa         2/12/2015
# Italy           Europe, Middle East, and Africa         2/12/2015
# Latvia          Europe, Middle East, and Africa         2/13/2015
# Lebanon         Europe, Middle East, and Africa         2/12/2015
# Ukraine                         857407           2413538          2/9/2017
# United Kingdom                20876148          51603774         2/10/2017
# United States                 85171450         166167230         2/10/2017
# Uruguay                         160641            572450          2/9/2017
#
#                Opening Day Sales 2017  Gross Sales 2017
# Country
# Argentina                     2238126           3724443
# Australia                     4732691          13785620
# Austria                       1019875           4628670
# Belgium                       1295138            619814
# Bolivia                        105252            339876
# Brazil                        7428179          21238913
# Bulgaria                       172707            520005
# Chile                          795764           2273168
# Colombia                       854643           1935725
# Croatia                        162397            222750
# Czech Republic                 903578           4415577
# Denmark                       1341920             53322
# Ecuador                        265210            984351
# Estonia                        124117            445120
# Finland                        472587           1610887
# France                        8272719          24886551
# Germany                       8529213          32709880
# Greece                         622757           1683324
# Hungary                        480052           1222196
# Iceland                         48159            143594
# Israel                         804738           2489791
# Italy                         6830852          15793926
# Latvia                          92280            393344
# Lebanon                        170619            477396
# Lithuania                      157108            580410
# Mexico                        2692197           6354100
# Netherlands                   1364618           6332203
# New Zealand                    372858           1317786
# Norway                        1445417           3529572
# Peru                           412266           1000712
# Philippines                   1803492           3399902
# Poland                        2709921           7392748
# Portugal                       715490           2489044
# Romania                        693489           1656543
# Singapore                      369593           1031387
# Slovakia                       496141           1106362
# Slovenia                       127642            538974
# South Africa                   760315           2465598
# South Korea                    655011           1379601
# Spain                         5065660          13961715
# Sweden                        1622542           5379401
# Thailand                       380099            768446
# Turkey                         552497           1788842
# Ukraine                        679391            159224
# United Kingdom                9241277          28583660
# United States                46607250         114581250
# Uruguay                        130478            310280

# %%
# Create a ScatterPlot comparings Opening Day Sales of 50 Shades Darker in 2017 vs World Happiness Rank 2017 by country

x = merged17_df['2017_rank']
y = merged17_df['Opening Day Sales 2017']
plt.scatter(x, y)
plt.title('Opening Day Sales 2015 vs Happiness Rank 2015')
plt.xlabel('Happiness Rank 2015')
plt.yticks(ticks=y_ticks_open,labels=y_labels_open)
plt.grid()
plt.tight_layout()
plt.savefig('Charts/2017OpeningSalesVSHappiness.png')

# %%
# Create a ScatterPlot comparings Gross Sales of 50 Shades Darker in 2017 vs World Happiness Rank 2017 by country

x = merged17_df['2017_rank']
y = merged17_df['Gross Sales 2017']
plt.scatter(x, y)
plt.title('Gross Sales 2017 vs World Happiness 2017')
plt.xlabel('Happiness Rank 2017')
plt.yticks(ticks=y_ticks_gross17,labels=y_labels_gross17)
plt.grid()
plt.tight_layout()
plt.savefig('Charts/2017GrossSalesVSHappiness.png')

# %%
# Build a dataframe which holds target countries, sales info for each movie, and happiness rank. Should be 5 Columns Long

# %%
# Create a ScatterPlot comparing Opening Day Sales of 50 Shades of Grey in 2015 vs World Happiness Rank 2015 with Target Countries

x = merged15_df['2015_rank']
y = merged15_df['Opening Day Sales 2015']
plt.scatter(x, y)
plt.title('Opening Day Sales 2015 vs Happiness Rank 2015')
plt.xlabel('Happiness Rank 2015')
plt.yticks(ticks=y_ticks_open,labels=y_labels_open)
plt.tight_layout()
plt.grid()
plt.savefig('Charts/2015OpeningSalesVSHappiness.png')
